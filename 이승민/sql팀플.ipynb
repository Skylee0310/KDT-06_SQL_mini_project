# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import koreanize_matplotlib

# %%
file2013 = './DATA/2013_입학정원_모집인원 및 입학자.xlsx'
file2014 = './DATA/2014_입학정원_모집인원 및 입학자.xlsx'
file2015 = './DATA/2015_입학정원_모집인원 및 입학자.xlsx'
file2016 = './DATA/2016_입학정원_모집인원 및 입학자.xlsx'
file2017 = './DATA/2017_입학정원_모집인원 및 입학자.xlsx'
file2018 = './DATA/2018_입학정원_모집인원 및 입학자.xlsx'
file2019 = './DATA/2019_입학정원_모집인원 및 입학자.xlsx'
file2020 = './DATA/2020_입학정원_모집인원 및 입학자.xlsx'
file2021 = './DATA/2021_입학정원_모집인원 및 입학자.xlsx'
file2022 = './DATA/2022_입학정원_모집인원 및 입학자.xlsx'

# %%
adm2013 = pd.read_excel(file2013)
adm2014 = pd.read_excel(file2014)
adm2015 = pd.read_excel(file2015)
adm2016 = pd.read_excel(file2016)
adm2017 = pd.read_excel(file2017)
adm2018 = pd.read_excel(file2018)
adm2019 = pd.read_excel(file2019)
adm2020 = pd.read_excel(file2020)
adm2021 = pd.read_excel(file2021)
adm2022 = pd.read_excel(file2022)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
adm2013
# Out:
#                                                     시도   구분    학제    입학정원  \
# 0                                                   시도   구분    학제     정원내
# 1                                                   시도   구분    학제     정원내
# 2                                                   시도   구분    학제     정원내
# 3                                                   전국   학부    대학  340980
# 4                                                   전국   학부  교육대학    3583
# ..                                                 ...  ...   ...     ...
# 201        - 신입생 충원률(%) = (정원내 입학자수) / (정원내 모집인원) ×100  NaN   NaN     NaN
# 202  - 대학원은 모집인원을 조사하지 않아 정원 내 모집인원 대신 입학정원으로 계산(대학...  NaN   NaN     NaN
# 203                                                NaN  NaN   NaN     NaN
# 204                                                 주석  NaN   NaN     NaN
# 205       출처: 한국교육개발원 교육통계서비스(https://kess.kedi.re.kr)  NaN   NaN     NaN
#
#     입학정원.1 입학정원.2 입학정원.3    모집인원 모집인원.1     입학자  ... 입학자.5 입학자.6 입학자.7 입학자.8  \
# ...

# %%
myadm2013 = adm2013.iloc[:,[7,18]]
myadm2014 = adm2014.iloc[:,[7,18]]
myadm2015 = adm2015.iloc[:,[7,18]]
myadm2016 = adm2016.iloc[:,[7,18]]
myadm2017 = adm2017.iloc[:,[7,18]]
myadm2018 = adm2018.iloc[:,[7,18]]
myadm2019 = adm2019.iloc[:,[7,18]]

# %%
myadm2013.columns = ["모집인원", "입학인원"]
myadm2014.columns = ["모집인원", "입학인원"]
myadm2015.columns = ["모집인원", "입학인원"]
myadm2016.columns = ["모집인원", "입학인원"]
myadm2017.columns = ["모집인원", "입학인원"]
myadm2018.columns = ["모집인원", "입학인원"]
myadm2019.columns = ["모집인원", "입학인원"]

# %%
alladm2013 = myadm2013.loc[15]
alladm2014 = myadm2014.loc[15]
alladm2015 = myadm2015.loc[15]
alladm2016 = myadm2016.loc[15]
alladm2017 = myadm2017.loc[15]
alladm2018 = myadm2018.loc[15]
alladm2019 = myadm2019.loc[15]

# %%
seouladm2013 = myadm2013.loc[35]
seouladm2014 = myadm2014.loc[35]
seouladm2015 = myadm2015.loc[35]
seouladm2016 = myadm2016.loc[35]
seouladm2017 = myadm2017.loc[35]
seouladm2018 = myadm2018.loc[35]
seouladm2019 = myadm2019.loc[35]

# %%
alladm2019
# Out:
# 모집인원    589243
# 입학인원    531329
# Name: 15, dtype: object

# %%
seouladm2019
# Out:
# 모집인원    172994
# 입학인원    172515
# Name: 35, dtype: object

# %%
myadm2020 = adm2020.iloc[:,[7,18]]
myadm2021 = adm2021.iloc[:,[7,18]]
myadm2022 = adm2022.iloc[:,[7,18]]

# %%
myadm2020.columns = ["모집인원", "입학인원"]
myadm2021.columns = ["모집인원", "입학인원"]
myadm2022.columns = ["모집인원", "입학인원"]

# %%
alladm2020 = myadm2020.loc[15]
alladm2021 = myadm2021.loc[15]
alladm2022 = myadm2022.loc[15]

# %%
seouladm2020 = myadm2020.loc[34]
seouladm2021 = myadm2021.loc[34]
seouladm2022 = myadm2022.loc[34]

# %%
alladm2022
# Out:
# 모집인원    568800
# 입학인원    483624
# Name: 15, dtype: object

# %%
seouladm2022
# Out:
# 모집인원    173742
# 입학인원    172405
# Name: 34, dtype: object

# %%
alladm = pd.concat([alladm2013,alladm2014,alladm2015,alladm2016,alladm2017,alladm2018,alladm2019,alladm2020,alladm2021,alladm2022], axis = 1, sort = True)
seouladm = pd.concat([seouladm2013,seouladm2014,seouladm2015,seouladm2016,seouladm2017,seouladm2018,seouladm2019,seouladm2020,seouladm2021,seouladm2022], axis = 1, sort = True)

# %%
alladm.columns = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
seouladm.columns = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
alladm = alladm.T
seouladm = seouladm.T

# %%
alladm
# Out:
#         모집인원    입학인원
# 2013  642828  594313
# 2014  648654  590908
# 2015  628228  575001
# 2016  613281  557173
# 2017  602132  541165
# 2018  594094  534749
# 2019  589243  531329
# 2020  583498  518786
# 2021  578681  487039
# 2022  568800  483624

# %%
seouladm
# Out:
#         모집인원    입학인원
# 2013  168528  132279
# 2014  180972  188376
# 2015  178659  184753
# 2016  177645  179565
# 2017  176492  175042
# 2018  175183  173996
# 2019  172994  172515
# 2020  171396  171751
# 2021  172817  175183
# 2022  173742  172405

# %%
alladm = alladm.astype('int64')
seouladm = seouladm.astype('int64')
otheradm = alladm-seouladm

# %%
otheradm
# Out:
#         모집인원    입학인원
# 2013  474300  462034
# 2014  467682  402532
# 2015  449569  390248
# 2016  435636  377608
# 2017  425640  366123
# 2018  418911  360753
# 2019  416249  358814
# 2020  412102  347035
# 2021  405864  311856
# 2022  395058  311219

# %%
seouladm.dtypes
# Out:
# 모집인원    int64
# 입학인원    int64
# dtype: object

# %%
alladm['충원율(%)'] = alladm['입학인원']/alladm['모집인원']*100
seouladm['충원율(%)'] = seouladm['입학인원']/seouladm['모집인원']*100
otheradm['충원율(%)'] = otheradm['입학인원']/otheradm['모집인원']*100

# %%
alladm
# Out:
#         모집인원    입학인원     충원율(%)
# 2013  642828  594313  92.452880
# 2014  648654  590908  91.097565
# 2015  628228  575001  91.527439
# 2016  613281  557173  90.851176
# 2017  602132  541165  89.874812
# 2018  594094  534749  90.010840
# 2019  589243  531329  90.171457
# 2020  583498  518786  88.909645
# 2021  578681  487039  84.163641
# 2022  568800  483624  85.025316

# %%
seouladm
# Out:
#         모집인원    입학인원      충원율(%)
# 2013  168528  132279   78.490815
# 2014  180972  188376  104.091241
# 2015  178659  184753  103.410967
# 2016  177645  179565  101.080807
# 2017  176492  175042   99.178433
# 2018  175183  173996   99.322423
# 2019  172994  172515   99.723112
# 2020  171396  171751  100.207123
# 2021  172817  175183  101.369078
# 2022  173742  172405   99.230468

# %%
otheradm
# Out:
#         모집인원    입학인원     충원율(%)
# 2013  474300  462034  97.413873
# 2014  467682  402532  86.069594
# 2015  449569  390248  86.804918
# 2016  435636  377608  86.679705
# 2017  425640  366123  86.017057
# 2018  418911  360753  86.116860
# 2019  416249  358814  86.201769
# 2020  412102  347035  84.210948
# 2021  405864  311856  76.837561
# 2022  395058  311219  78.778053

# %%
plt.figure(figsize=(14,6))
plt.title("전국 대학 신입생 충원율",fontsize='xx-large')
plt.plot(alladm.index, alladm["충원율(%)"])
plt.xticks(range(2013,2023), range(2013,2023))
plt.xlabel("연(년)", loc = 'right')
plt.ylabel("%", loc = 'top', rotation=180)
# Out:
# Text(0, 1, '%')

# %% [markdown]
# ## 연도별 신입생 충원율과 일치(KESS의 자료)

# %%
plt.figure(figsize=(14,6))
plt.title("서울 대학 신입생 충원율",fontsize='xx-large')
plt.plot(seouladm.index, seouladm["충원율(%)"])
plt.xticks(range(2013,2023), range(2013,2023))
plt.xlabel("연(년)", loc = 'right')
plt.ylabel("%", loc = 'top', rotation=180)
# Out:
# Text(0, 1, '%')

# %%
plt.figure(figsize=(14,6))
plt.title("지방 대학 신입생 충원율",fontsize='xx-large')
plt.plot(otheradm.index, otheradm["충원율(%)"])
plt.xticks(range(2013,2023), range(2013,2023))
plt.xlabel("연(년)", loc = 'right')
plt.ylabel("%", loc = 'top', rotation=180)
# Out:
# Text(0, 1, '%')

# %% [markdown]
# ## 출처 : 교육통계서비스 KESS

# %%
plt.figure(figsize=(14,6))
plt.plot(alladm.index, alladm["충원율(%)"], label = '전국 대학 신입생 충원율', marker = 'o')
plt.plot(seouladm.index, seouladm["충원율(%)"], label = '서울 대학 신입생 충원율', marker = 'o')
plt.plot(otheradm.index, otheradm["충원율(%)"], label = '지방 대학 신입생 충원율', marker = 'o')
plt.xticks(range(2013,2023), range(2013,2023))
plt.title("[신입생 충원율]", fontsize = 'xx-large')
plt.xlabel("년도",loc = 'right', fontsize = 'large')
plt.ylabel("%", fontsize = 'large', rotation = 180)
plt.legend(loc = 7)
plt.show()

# %%
import pymysql

# %%
def init_table(conn, cur, database, table, df):
    sqlCreateTable = f"""-- sql
        CREATE TABLE {table} (
            연도 SMALLINT UNSIGNED NOT NULL,
            모집인원 MEDIUMINT UNSIGNED,
            입학인원 MEDIUMINT UNSIGNED,
            충원율 FLOAT(4,1),
            CONSTRAINT fk_{table} FOREIGN KEY (연도) REFERENCES population_table (연도)
        )"""
    create_table(conn, cur, database, table, sqlCreateTable)

    for i in range(df.shape[0]):
        sqlInsertData = f"""-- sql
            INSERT INTO {table} (연도, 모집인원, 입학인원, 충원율)
            VALUES {tuple(df.iloc[i].to_list())}"""
        insert_data(conn, cur, database, table, sqlInsertData)


def create_table(conn, cur, databaseName, tableName, sqlCreate):
    try:
        sqlUse = f"""-- sql
            USE {databaseName}"""
        sql_fk_checks0 = f"""-- sql
            SET foreign_key_checks = 0"""
        sqlDrop = f"""-- sql
            DROP TABLE IF EXISTS {tableName}"""
        sql_fk_checks1 = f"""-- sql
            SET foreign_key_checks = 1"""

        cur.execute(sqlUse)
        cur.execute(sql_fk_checks0)
        cur.execute(sqlDrop)
        cur.execute(sql_fk_checks1)
        cur.execute(sqlCreate)
        conn.commit()
        print(f"{tableName} Table 생성 완료")
    except Exception as e:
        print(e)  # 에러메세지 출력


def insert_data(conn, cur, databaseName, tableName, sqlInsert):
    try:
        sqlUse = f"""-- sql
            USE {databaseName}"""
        
        cur.execute(sqlUse)
        cur.execute(sqlInsert)
        conn.commit()
        print(f"{tableName} Table 데이터 추가 완료")
    except Exception as e:
        print(e)  # 에러메세지 출력

# %%
conn = pymysql.connect(host='localhost', port=3306,
                        user='root', passwd='1234', db='schoolage', charset='utf8')
cur = conn.cursor(pymysql.cursors.DictCursor)

# %%
alladm1 = alladm.reset_index().rename(columns={'index': '연도'})
seouladm1 = seouladm.reset_index().rename(columns={'index': '연도'})
otheradm1 = otheradm.reset_index().rename(columns={'index': '연도'})

# %%
alladm1
# Out:
#      연도    모집인원    입학인원     충원율(%)
# 0  2013  642828  594313  92.452880
# 1  2014  648654  590908  91.097565
# 2  2015  628228  575001  91.527439
# 3  2016  613281  557173  90.851176
# 4  2017  602132  541165  89.874812
# 5  2018  594094  534749  90.010840
# 6  2019  589243  531329  90.171457
# 7  2020  583498  518786  88.909645
# 8  2021  578681  487039  84.163641
# 9  2022  568800  483624  85.025316

# %%
seouladm1
# Out:
#      연도    모집인원    입학인원      충원율(%)
# 0  2013  168528  132279   78.490815
# 1  2014  180972  188376  104.091241
# 2  2015  178659  184753  103.410967
# 3  2016  177645  179565  101.080807
# 4  2017  176492  175042   99.178433
# 5  2018  175183  173996   99.322423
# 6  2019  172994  172515   99.723112
# 7  2020  171396  171751  100.207123
# 8  2021  172817  175183  101.369078
# 9  2022  173742  172405   99.230468

# %%
otheradm1
# Out:
#      연도    모집인원    입학인원     충원율(%)
# 0  2013  474300  462034  97.413873
# 1  2014  467682  402532  86.069594
# 2  2015  449569  390248  86.804918
# 3  2016  435636  377608  86.679705
# 4  2017  425640  366123  86.017057
# 5  2018  418911  360753  86.116860
# 6  2019  416249  358814  86.201769
# 7  2020  412102  347035  84.210948
# 8  2021  405864  311856  76.837561
# 9  2022  395058  311219  78.778053

# %%
init_table(conn, cur, 'schoolage', '전국_대학_신입생_충원율', alladm1)
# Out:
# 전국_대학_신입생_충원율 Table 생성 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료
# 전국_대학_신입생_충원율 Table 데이터 추가 완료

# %%
init_table(conn, cur, 'schoolage', '서울_대학_신입생_충원율', seouladm1)
# Out:
# 서울_대학_신입생_충원율 Table 생성 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료
# 서울_대학_신입생_충원율 Table 데이터 추가 완료

# %%
init_table(conn, cur, 'schoolage', '지방_대학_신입생_충원율', otheradm1)
# Out:
# 지방_대학_신입생_충원율 Table 생성 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
# 지방_대학_신입생_충원율 Table 데이터 추가 완료
